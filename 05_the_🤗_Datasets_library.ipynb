# %% [markdown]
# <a href="https://colab.research.google.com/github/educatorsRlearners/hugging_face_course/blob/main/05_the_%F0%9F%A4%97_Datasets_library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install datasets transformers[sentencepiece]

# %% [markdown]
# # Introduction
#
# To review, there are three main steps to fine-tuning a mode:
#
# 1. Load a dataset from the Hugging Face Hub
# 2. Preprocess the data with ```Dataset.map()```
# 3. Load and compute metrics
#
# But,  what if
# - your data isn't on the Hub?
# - you ***really*** need to use ```Pandas```?
# - the data set can't fit into your computer's RAM?
# - you want to push your own data to the the Hub?
#
# Well, that's what this chapter is for 😀
#
# # [What if my dataset isn't on the Hub?](https://huggingface.co/course/chapter5/2?fw=pt)
#
# ## Working with local and remote datasets
#
# We simply have to pass the file type (e.g., csv, text, json) as well as the location of the file to ```load_dataset``` like so:

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv

# %%
from datasets import load_dataset

# local_csv_dataset = load_dataset("csv", 
#                                  data_files= "winequality-white.csv",
#                                  sep=";")

# %%
# local_csv_dataset['train'][:5]

# %% [markdown]
# Now imagine you want to load the train and test together so that you can you ```Dataset.map()``` for preprocessing.
#
# To do so, we pass a dictionary to ```load_dataset``` explaining which file is trian and which is test like this:

# %%
# data_files = {"train": "SQuAD_it-train.json", "test": "SQuAD_it-test.json"}
# squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# squad_it_dataset

# %%
data_files = {"train": "sample_data/california_housing_train.csv", 
              "test": "sample_data/california_housing_test.csv"}

housing_dataset = load_dataset("csv", data_files=data_files)
# Out:
# Using custom data configuration default-5a2d12c9cd054b87
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-5a2d12c9cd054b87/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
housing_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value'],
#         num_rows: 17000
#     })
#     test: Dataset({
#         features: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value'],
#         num_rows: 3000
#     })
# })

# %% [markdown]
# ## Remote Files
#
# For remote files, we simply pass the URL to ```data_files``` like this:

# %%
url = "https://raw.githubusercontent.com/educatorsRlearners/podrevday/master/data/user_data.csv"
prd = load_dataset('csv', data_files=url)
# Out:
# Using custom data configuration default-e8d5249814fd0fe4
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/42.0k [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-e8d5249814fd0fe4/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prd
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'id', 'username', 'displayname', 'location', 'created', 'followersCount', 'friendsCount', 'url', 'verified', 'geotext', 'city', 'country'],
#         num_rows: 640
#     })
# })

# %% [markdown]
# ## Raw Text
#
# When working with text files, we simply load it the same way:

# %%
url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"

text_file = load_dataset("text", data_files=url)
# Out:
# Using custom data configuration default-599a481abc93904d
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/435k [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-599a481abc93904d/0.0.0/d86c40dad297bdddf277b406c6a59f0250b5318c400bf23d420a31aff88c84c4. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
text_file['train'][:5]
# Out:
# {'text': ['First Citizen:',
#   'Before we proceed any further, hear me speak.',
#   '',
#   'All:',
#   'Speak, speak.']}

# %% [markdown]
# # [Time to slice and dice](https://huggingface.co/course/chapter5/3?fw=pt)
#
# ## Slicing and dicing our data
#
# Life is not a Kaggle competition; we will always need to format it before we do anything else.
#
# Luckily, the people at 🤗 know that and have built some functionality into the ```dataset``` library.
#
# To explore these features, we'll use the Drug Review Dataset from UC Irvine's Machine Learning Reposity.

# %%
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip"
# !unzip drugsCom_raw.zip
# Out:
# --2022-01-30 18:54:20--  https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42989872 (41M) [application/x-httpd-php]
# Saving to: ‘drugsCom_raw.zip’
#
# drugsCom_raw.zip    100%[===================>]  41.00M  30.6MB/s    in 1.3s
#
# 2022-01-30 18:54:22 (30.6 MB/s) - ‘drugsCom_raw.zip’ saved [42989872/42989872]
#
# Archive:  drugsCom_raw.zip
#   inflating: drugsComTest_raw.tsv
#   inflating: drugsComTrain_raw.tsv

# %% [markdown]
# As we previously saw, we can pass a dictionary to the ```data_files``` argument as well as specify the delimiter.

# %%
data_files = {'train': "drugsComTrain_raw.tsv",
              "test": "drugsComTest_raw.tsv"}

drug_dataset = load_dataset('csv', 
                            data_files=data_files,
                            delimiter="\t")
# Out:
# Using custom data configuration default-3761173c276c0a9a
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-3761173c276c0a9a/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# Now we can have a look at a random sample to make sure everythign is copacetic.
#
# To do so, we'll:
# - shuffle the dataset
# - select the first 1000 examples

# %%
drug_sample = drug_dataset["train"].shuffle(seed=42).select(range(1000))

drug_sample[:3]
# Out:
# {'Unnamed: 0': [87571, 178045, 80482],
#  'condition': ['Gout, Acute', 'ibromyalgia', 'Inflammatory Conditions'],
#  'date': ['September 2, 2015', 'November 7, 2011', 'June 5, 2013'],
#  'drugName': ['Naproxen', 'Duloxetine', 'Mobic'],
#  'rating': [9.0, 3.0, 10.0],
#  'review': ['"like the previous person mention, I&#039;m a strong believer of aleve, it works faster for my gout than the prescription meds I take. No more going to the doctor for refills.....Aleve works!"',
# ...

# %% [markdown]
# OK, it looks like ```Unnamed: 0``` is the id column and the others could use some general cleaning (e.g., converting to lower-case, removing html as well as carriage returns) so let's do that.
#
# But, let's verify that each value in ```Unnamed: 0``` is unique.

# %%
for split in drug_dataset.keys():
  assert len(drug_dataset[split]) == len(drug_dataset[split].unique("Unnamed: 0"))

# %% [markdown]
# Score!
#
# In that case, let's rename it to something useful.

# %%
drug_dataset = drug_dataset.rename_column(
    original_column_name="Unnamed: 0",
    new_column_name="patient_id"
)

drug_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 161297
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 53766
#     })
# })

# %% [markdown]
# ✏️ Try it out! Use the ```Dataset.unique()``` function to find the number of unique drugs and conditions in the training and test sets.

# %%
number_unique_drugs = len(drug_dataset['train'].unique('drugName'))

number_unique_conditions = len(drug_dataset['train'].unique('condition'))

print(f'There are {number_unique_drugs} drugs and {number_unique_conditions} \
unique conditions in the dataset.' )
# Out:
# There are 3436 drugs and 885 unique conditions in the dataset.

# %% [markdown]
# Now let's fix the case issue.
#
# First, we'll remove all observations where the condition equals ```None```.

# %%
def filter_nones(x):
  return x["condition"] is not None

# %%
drug_dataset = drug_dataset.filter(filter_nones)
# Out:
# ...
#   0%|          | 0/54 [00:00<?, ?ba/s]

# %% [markdown]
# Alternatively, we could have just used a lambda function like this:

# %%
drug_dataset = drug_dataset.filter(lambda x: x["condition"] is not None)
# Out:
# ...
#   0%|          | 0/54 [00:00<?, ?ba/s]

# %% [markdown]
# Now we can normalize the condition column using the ```map()``` method which simply replaces one value for another.

# %%
def lowercase_condition(example):
  return {"condition": example['condition'].lower()}

drug_dataset = drug_dataset.map(lowercase_condition)
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %% [markdown]
# ## [Creating New Columns](https://huggingface.co/course/chapter5/3?fw=pt#creating-new-columns)
#
# It's always a good idea to identify how long a review is.
#
# How do we do that?
#
# Like this:

# %%
def compute_review_length(example):
  return {"review_length": len(example["review"].split())}

drug_dataset = drug_dataset.map(compute_review_length)
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
drug_dataset['train'][0]
# Out:
# {'condition': 'left ventricular dysfunction',
#  'date': 'May 20, 2012',
#  'drugName': 'Valsartan',
#  'patient_id': 206461,
#  'rating': 9.0,
#  'review': '"It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil"',
#  'review_length': 17,
#  'usefulCount': 27}

# %% [markdown]
# Now we can sort our dataset by review length.

# %%
drug_dataset['train'].sort('review_length')[:3]
# Out:
# {'condition': ['birth control', 'muscle spasm', 'pain'],
#  'date': ['November 4, 2008', 'March 24, 2017', 'August 20, 2016'],
#  'drugName': ['Loestrin 21 1 / 20', 'Chlorzoxazone', 'Nucynta'],
#  'patient_id': [103488, 23627, 20558],
#  'rating': [10.0, 1.0, 6.0],
#  'review': ['"Excellent."', '"useless"', '"ok"'],
#  'review_length': [1, 1, 1],
#  'usefulCount': [5, 2, 10]}

# %% [markdown]
# Let's filter out those super short reviews.

# %%
drug_dataset = drug_dataset.filter(lambda x: x['review_length'] > 30)

print(drug_dataset.num_rows)
# Out:
# ...
#   0%|          | 0/54 [00:00<?, ?ba/s]
# {'train': 138514, 'test': 46108}

# %% [markdown]
# ✏️ Try it out! Use the ```Dataset.sort()``` function to inspect the reviews with the largest numbers of words. See the [documentation](https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.sort) to see which argument you need to use sort the reviews by length in descending order.

# %%
drug_dataset['train'].sort('review_length', reverse=True)[:3]
# Out:
# {'condition': ['migraine', 'obsessive compulsive disorde', 'birth control'],
#  'date': ['June 18, 2017', 'May 26, 2017', 'September 17, 2015'],
#  'drugName': ['Venlafaxine', 'Prozac', 'Copper'],
#  'patient_id': [121004, 181160, 216072],
#  'rating': [2.0, 10.0, 10.0],
# ...

# %% [markdown]
# And now we can finally get rid of the HTML character codes like this:

# %%
import html

text = "I&#039;m a transformer called BERT"
html.unescape(text)
# Out:
# "I'm a transformer called BERT"

# %% [markdown]
# Again, map will be our friend 😀

# %%
drug_dataset = drug_dataset.map(lambda x: {"review": html.unescape(x['review'])})
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %% [markdown]
# ## [The ```map()``` method's superpowers](https://huggingface.co/course/chapter5/3?fw=pt#the-%3Ccode%3Emap()%3C/code%3E-method%E2%80%99s-superpowers)
#
# ***Key Point***: ```map()``` takes a ```batched``` argument which we can use to speed up processing via list comprehension like this:

# %%
new_drug_dataset = drug_dataset.map(
    lambda x: {"review": [html.unescape(o) for o in x["review"]]},
    batched=True
)
# Out:
# ...
#   0%|          | 0/47 [00:00<?, ?ba/s]

# %% [markdown]
# As we can clearly see, the which made use of batches ran significantly faster.
#
# ***Key Point***: using ```Dataset.map(batched=True)``` is essential for using **fast** tokenizers.
#
# For instance, to toknize our drug reviews, we could do something like this:

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

def tokenize_function(examples):
  return tokenizer(examples['review'], truncation=True)
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %% [markdown]
# Now, to tokenize our dataset in batches, we pass our ```tokenize_function``` to ```map()``` and set ```batched``` to ```True```.

# %%
# %%time 
tokenize_dataset = drug_dataset.map(tokenize_function, batched=True)
# Out:
# ...
#   0%|          | 0/47 [00:00<?, ?ba/s]
# CPU times: user 1min 29s, sys: 702 ms, total: 1min 29s
# Wall time: 56.2 s

# %% [markdown]
# ✏️ Try it out! Execute the same instruction with and without ```batched=True```, then try it with a slow tokenizer (add ```use_fast=False``` in the ```AutoTokenizer.from_pretrained()``` method) so you can see what numbers you get on your hardware.

# %%
# Fast, batched=False

# %%time 
tokenize_dataset = drug_dataset.map(tokenize_function, batched=False)
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]
# CPU times: user 2min 3s, sys: 1.09 s, total: 2min 4s
# Wall time: 2min 9s

# %%
slow_tokenizer = AutoTokenizer.from_pretrained("bert-base-cased",
                                               use_fast=False)

def tokenize_function(examples):
  return slow_tokenizer(examples['review'], truncation=True)

# %%
# Slow, batched=True
# %%time 
# tokenize_dataset = drug_dataset.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/139 [00:00<?, ?ba/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-81a0a4e8886f> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'tokenize_dataset = drug_dataset.map(tokenize_function, batched=True)')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-53> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# ...

# %%
# Slow, batched=False
# %%time 
# tokenize_dataset = drug_dataset.map(tokenize_function, batched=False)

# %% [markdown]
# In essence, by batching, we are taking advantage of parrareliztion.
#
# To further speed up the process, we can set the number of processors we have by passing ```num_proc``` to ```map()``` like this:

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

def tokenize_function(examples):
  return tokenizer(examples['review'], truncation=True)

# %%
# %%time 
tokenize_dataset = drug_dataset.map(tokenize_function, 
                                    batched=True,
                                    num_proc=8)

# %% [markdown]
# Now we're going to do something REALLY cool: let's tokenize the first 128 tokens of passage and then return the remaining chunks instead of just discarding them.
#
# ***How????***
#
# Like this:

# %%
def tokenize_and_split(examples):
  return tokenizer(
      examples["review"],
      truncation=True,
      max_length=128,
      return_overflowing_tokens=True
  )

# %% [markdown]
# Now this function should work on the entire dataset but, in the spirit of unit testing, we'll try it out on a single example first.

# %%
result = tokenize_and_split(drug_dataset['train'][0])

[len(inp) for inp in result["input_ids"]]

# %% [markdown]
# Perfect!
#
# Unfortunately, that apporach won't work for the entire dataset:

# %%
tokenized_dataset = drug_dataset.map(tokenize_and_split, batched=True)

# %% [markdown]
# To avoid this error, we either need to remove columns from the old dataset or ensure the new dataset is the same shape as the old one.
#
# I'm going to do the first approach but, if you want to see how to do the first, click [here](https://huggingface.co/course/chapter5/3?fw=pt#:~:text=def%20tokenize_and_split(examples)%3A%0A%20%20%20%20result,in%20sample_map%5D%0A%20%20%20%20return%20result).

# %%
tokenized_dataset = drug_dataset.map(tokenize_and_split,
                                     batched=True,
                                     remove_columns=drug_dataset['train'].column_names)

# %% [markdown]
# ## [From Datasets to DataFrames and back](https://huggingface.co/course/chapter5/3?fw=pt#from-%3Ccode%3Edataset%3C/code%3Es-to-%3Ccode%3Edataframe%3C/code%3Es-and-back)
#
# Sometimes, you really, really, REALLY just want/need to use ```pandas```, ```NumPy```, or some other library. Luckily, it is really simple to do so.
#
# The first option is to use the ```set_format()``` method on our ```Dataset```.

# %%
drug_dataset.set_format("pandas")

# %%
drug_dataset["train"][:3]
# Out:
#    patient_id    drugName  ... usefulCount review_length
# 0       95260  Guanfacine  ...         192           141
# 1       92703      Lybrel  ...          17           134
# 2      138000  Ortho Evra  ...          10            89
#
# [3 rows x 8 columns]

# %% [markdown]
# Now to create a ```pd.DataFrame``` we select all the elements like so:

# %%
train_df = drug_dataset['train'][:]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138514 entries, 0 to 138513
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   patient_id     138514 non-null  int64
#  1   drugName       138514 non-null  object
#  2   condition      138514 non-null  object
#  3   review         138514 non-null  object
#  4   rating         138514 non-null  float64
#  5   date           138514 non-null  object
#  6   usefulCount    138514 non-null  int64
#  7   review_length  138514 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 8.5+ MB

# %% [markdown]
# The second option is to use the ```.to_pandas()``` method on our ```Dataset```.

# %%
df = drug_dataset['train'].to_pandas()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138514 entries, 0 to 138513
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   patient_id     138514 non-null  int64
#  1   drugName       138514 non-null  object
#  2   condition      138514 non-null  object
#  3   review         138514 non-null  object
#  4   rating         138514 non-null  float64
#  5   date           138514 non-null  object
#  6   usefulCount    138514 non-null  int64
#  7   review_length  138514 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 8.5+ MB

# %% [markdown]
# Now we can do any fancy data analysis we want using ```pandas``` functionality.
#
# ✏️ Try it out! Compute the average rating per drug and store the result in a new Dataset.

# %%
avg_drug_ratings = (df
                    .loc[:, ['drugName', 'rating']]
                    .groupby('drugName')
                    .mean('rating')
                    .reset_index()
)

avg_drug_ratings.head()
# Out:
#                                drugName     rating
# 0             A + D Cracked Skin Relief  10.000000
# 1                            A / B Otic  10.000000
# 2  Abacavir / dolutegravir / lamivudine   7.953488
# 3    Abacavir / lamivudine / zidovudine   9.000000
# 4                             Abatacept   7.312500

# %% [markdown]
# To revert it back to a 🤗Dataset, we use the ```.reset_format()``` method.

# %%
drug_dataset.reset_format()

# %% [markdown]
# ## [Creating a validation set](https://huggingface.co/course/chapter5/3?fw=pt#creating-a-validation-set)
#
# Again, it is best practice to split your data into three:
# - train
# - validate
# - test
#
# And 🤗Datasets makes use of ```scikit-learn```'s functionality so we can easily create our train-validate-test split like so:

# %%
drug_dataset_clean = drug_dataset["train"].train_test_split(train_size=0.8,
                                                            seed=42)

#Rename the default "test" split to "validation"
drug_dataset_clean['validation'] = drug_dataset_clean.pop('test')

#Add the "test" set to our 'DatasetDict
drug_dataset_clean['test'] = drug_dataset['test']

drug_dataset_clean
# Out:
# Loading cached split indices for dataset at /root/.cache/huggingface/datasets/csv/default-3761173c276c0a9a/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e/cache-7f0de61cf8e730bd.arrow and /root/.cache/huggingface/datasets/csv/default-3761173c276c0a9a/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e/cache-42455de2a26961f9.arrow
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 110811
#     })
#     validation: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 27703
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 46108
#     })
# })

# %% [markdown]
# ## Saving a dataset
#
# We can save our dataset in either Arrow, CSV, or JSON formats (see below).

# %%
#Arrow
drug_dataset_clean.save_to_disk("drug-reviews")

#CSV
# drug_dataset_clean.to_csv("drug-reviews")

#JSON
# drug_dataset_clean.to_json("drug-reviews")
# Out:
# ...
# Flattening the indices:   0%|          | 0/28 [00:00<?, ?ba/s]

# %% [markdown]
# Loading our saved dataset is just as easy if you save it as an Arrow object.

# %%
from datasets import load_from_disk

drug_dataset_reloaded = load_from_disk("drug-reviews")

drug_dataset_reloaded
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 110811
#     })
#     validation: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 27703
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 46108
#     })
# })

# %% [markdown]
# Please not that we have to save each split as a seperate csv or json file so, to make your life easy, save it as Arrow when possible.
#
# # [Big data? 🤗 Datasets to the rescue!](https://huggingface.co/course/chapter5/4?fw=pt)
#
# If you're working with gigs of data, you can't reasonably expect to load it all into memory, or can you?
#
# No, you can't, but, in this section, we explore how 🤗 Datasets makes use of *memory-mapped files* and *streaming* to avoid memory management problems and hard drive limits.
#
# ## [What is Pile?](https://huggingface.co/course/chapter5/4?fw=pt#what-is-the-pile?)
#
# To demonstrate, we'll use The Pile which is the 825 English text corpus created by EleutherAI.
#
# We're not actually going to download the entire thing; just about 16 million rows.

# %%
# Download the Data
# !pip install zstandard
# Out:
# ...
#      |████████████████████████████████| 2.5 MB 13.7 MB/s
# ...

# %% [markdown]
# Now we load the dataset

# %%
# from datasets import load_dataset

# data_files = "https://the-eye.eu/public/AI/pile_preliminary_components/PUBMED_title_abstracts_2019_baseline.jsonl.zst"


# pubmed_dataset = load_dataset("json", 
#                               data_files=data_files, 
#                               split="train")

# pubmed_dataset

# %% [markdown]
# Or we would except The Pile is currently down so we'll revisit this topic at a later date.
